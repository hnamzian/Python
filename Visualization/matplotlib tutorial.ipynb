# %% [markdown]
# # matplolib

# %% [markdown]
# ### Resources:

# %% [markdown]
# ### import

# %%
# %matplotlib inline

# %%
from pylab import *

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ## MATLAB-Like Plot:
#
# ### APIs:
# - __plot()__
# - __subplot()__

# %% [markdown]
# ### plot

# %%
x = np.linspace(-5,5,25)
y = 5*x**2
z = x**3

# %%
plot(x, y)
xlabel('x')
ylabel('y')
title('title')
show()

# %%
plot(x, y, 'r', x, z, 'b')
xlabel('x')
ylabel('y/z')
title('title')
show()

# %% [markdown]
# ### subplot

# %%
subplot(1,2,1)
plot(x, y, 'r--')
subplot(1,2,2)
plot(x, z, 'b*-')

# %% [markdown]
# ## object-oriented API

# %% [markdown]
# ### Ways of plot creation:
# 1. __Create a figure and using add_axes to create seperate plots.   (*plt.figure() + fig.add_axes() + axes.plot()*)__
# 2. __Create a subplots object that contains figure and axes.   (*fig, ax = plt.subplots() + ax.plot()*)__

# %% [markdown]
# ### plot

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #[Left, Buttom, Width, Height]

axes.plot(x, y, 'r')

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.9])
axes2 = fig.add_axes([0.2, 0.6, 0.3, 0.3])

axes1.plot(x, z, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('z')
axes1.set_title('title')

axes2.plot(x, y, 'b')
axes2.set_xlabel('x')
axes2.set_ylabel('y')
axes2.set_title('title')

# %% [markdown]
# ### subplot

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y,'r')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('$x=5y^2$')

axes[1].plot(x,z,'b')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')
axes[1].set_title('$x=y^3$')

# %% [markdown]
# ### Figure size, aspect ratio and DPI

# %%
fig = plt.figure(figsize=(4,6), dpi=100) # figsize in inch, dpi:pixel per inch

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 

axes.plot(x, y, 'r')

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))

axes[0].plot(x,y,'r')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('$x=5y^2$')

axes[1].plot(x,z,'b')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')
axes[1].set_title('$x=y^3$')

# %% [markdown]
# ### Svaing figure
# __Supporting formats are: PNG, JPG, EPS, SVG, PGF and PDF__

# %%
fig.savefig('./figtest.png', dpi=100)
fig.savefig('./figtest.pdf', dpi=100)

# %% [markdown]
# ### Legends

# %% [markdown]
# #### method 1:

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'r', label='$y=5x^2$')
ax.plot(x, z, 'b', label='$y=x^3$')
ax.legend(loc=0)  # let matplotlib decide the optimal location
#ax.legend(loc=1) # upper right corner
#ax.legend(loc=2) # upper left corner
#ax.legend(loc=3) # lower left corner
#ax.legend(loc=4) # lower right corner 

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')

# %% [markdown]
# #### method 2:

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'r', x, z, 'b')
ax.legend(['$y=5x^2$', '$y=x^3$'], loc=0)  # let matplotlib decide the optimal location

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')

# %% [markdown]
# ### matplotlib reconfiguration:

# %%
matplotlib.rcParams.update({'font.size': 18, 'font.family': 'serif'})

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'r', x, z, 'b')
ax.legend(['$y=5x^2$', '$y=x^3$'], loc=0)  # let matplotlib decide the optimal location

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')

# %% [markdown]
# __STIX Font__

# %%
matplotlib.rcParams.update({'font.size': 18, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'r', x, z, 'b')
ax.legend(['$y=5x^2$', '$y=x^3$'], loc=0)  # let matplotlib decide the optimal location

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')

# %% [markdown]
# ### restore configs

# %%
matplotlib.rcParams.update({'font.size': 12, 'font.family': 'sans', 'text.usetex': False})

# %% [markdown]
# ### Setting colors, linewidths, linetypes

# %% [markdown]
# __Color__

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color='red', alpha=0.5)  #using color+alpha
ax.plot(x, x+3, color='#1155dd')         #using color code
ax.plot(x, x+5, color="#15cc55")

# %% [markdown]
# #### Linewidth, Linestyle, Marker

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.plot(x,x+1, color='blue', linewidth=0.25)
ax.plot(x,x+2, color='blue', linewidth=0.5)
ax.plot(x,x+3, color='blue', linewidth=1)
ax.plot(x,x+4, color='blue', linewidth=2)

ax.plot(x,x+5, color='red', lw=2, linestyle='-')
ax.plot(x,x+6, color='red', lw=2, ls='-.')
ax.plot(x,x+7, color='red', lw=2, ls=':')

line, = ax.plot(x,x+8, color='black', lw=1.5)
line.set_dashes([5,10,15,10])

ax.plot(x,x+9, color='green', lw=2, ls='--', marker='+')
ax.plot(x,x+10, color='green', lw=2, ls='--', marker='o')
ax.plot(x,x+11, color='green', lw=2, ls='--', marker='s')
ax.plot(x,x+12, color='green', lw=2, ls='--', marker='1')

ax.plot(x,x+13, color='purple', lw=1, ls='-', marker='o', markersize=2)
ax.plot(x,x+14, color='purple', lw=1, ls='-', marker='o', markersize=4)
ax.plot(x,x+15, color='purple', lw=1, ls='-', marker='o', markersize=8, markerfacecolor='red')
ax.plot(x,x+16, color='purple', lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor='yellow', markeredgewidth=2, markeredgecolor='blue')

# %% [markdown]
# ### Control over axis appearance

# %% [markdown]
# #### Plot range

# %%
fig, axes = plt.subplots(1, 3, figsize=(12,4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title('default axes range')

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_xlim([-3,3])
axes[2].set_ylim([-60,60])
axes[2].set_title('costum axes range')

# %% [markdown]
# ##### logarithmic scale

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title('Normal Scale')

axes[1].plot(x, x**2, x, x**3)
axes[1].set_yscale('log')
axes[1].set_title('Logaritmic Scale')

# %% [markdown]
# ### tick placement

# %%
fig, ax = plt.subplots(figsize=(10,4))

ax.plot(x, 3*x**2, x, x**3, lw=2)

ax.set_xticks([-5, -2.5, 0, 2.5, 5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\omega$', r'$\sigma$', r'$\delta$'], fontsize=18)

yticks = [-100, -50, 0, 50, 100]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18);

# %% [markdown]
# #### Scientific notation

# %%
fig, ax = plt.subplots(1,1)

ax.plot(x, x**2, x, np.exp(x))
ax.set_title('scientific notations')

ax.set_yticks([0, 50, 100, 150])

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits([-1,1])
ax.yaxis.set_major_formatter(formatter)

# %% [markdown]
# ### Axis number and axis label spacing

# %% [markdown]
# #### axis-number distance and number-label distance

# %%
# set the distance between axis and numbers
matplotlib.rcParams['xtick.major.pad'] = 10
matplotlib.rcParams['ytick.major.pad'] = 15

fig, axes= plt.subplots()
axes.plot(x, x**2, x, np.exp(x))
axes.set_yticks([0, 50, 100, 150])

# set distance between label and numbers
axes.xaxis.labelpad = 5
axes.yaxis.labelpad = 20

axes.set_xlabel('x')
axes.set_ylabel('y')

# %%
#restore to defaults
matplotlib.rcParams['xtick.major.pad'] = 3
matplotlib.rcParams['ytick.major.pad'] = 3

# %% [markdown]
# #### Axis position

# %%
fig, axes= plt.subplots()
axes.plot(x, x**2, x, np.exp(x))
axes.set_yticks([0, 50, 100, 150])

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')

fig.subplots_adjust(left=0.15, right=1.5, bottom=0.1, top=0.9)

# %% [markdown]
# ### Axis grid

# %%
fig, axes= plt.subplots(1,2)
axes[0].plot(x, x**2)
axes[0].grid(True)

axes[1].plot(x, x**3)
axes[1].grid(color='b', alpha=0.75, linestyle='dashed', linewidth=0.5)

# %% [markdown]
# #### Axis spines

# %%
fig, ax = plt.subplots(figsize=(6,2))

ax.spines['bottom'].set_color('blue')
ax.spines['top'].set_color('blue')

ax.spines['left'].set_color('red')
ax.spines['left'].set_linewidth(2)

ax.spines['right'].set_color('none')

ax.xaxis.tick_bottom()
ax.yaxis.tick_left()

# %% [markdown]
# #### Twin axes

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, x**2, lw=2, color='red')
ax1.set_xlabel('x')
ax1.set_ylabel('$area(m^2)$', fontsize=18, color='blue')

for label in ax1.get_yticklabels():
    label.set_color('blue')
    
ax2 = ax1.twinx()
ax2.plot(x, x**3, lw=2, color='blue')
ax2.set_ylabel('$volume(m^3)$', fontsize=18, color='red')

for label in ax2.get_yticklabels():
    label.set_color('red')

# %% [markdown]
# ### Axes where x and y is zero

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

ax.plot(x, x**3)

# %% [markdown]
# ### Other 2D plot styles

# %%
x = np.linspace(0, 5, 50)
y = x + np.random.rand(50)

n = np.arange(5)

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(x, y)
axes[0].set_title('scatter')

axes[1].step(n, n**2, lw=2)
axes[1].set_title('step')

axes[2].bar(n, n**2, align='center', width=0.5, color='blue', alpha=0.5)
axes[2].set_title('bar')

axes[3].fill_between(x, x**2, x**3, color='green', alpha=0.35)
axes[3].set_title('fill_between')

# %%
x = np.random.random(50)
y = np.random.random(50)
c = np.random.random(50)
s = 500*np.random.random(50)

fig, ax = plt.subplots()
im = ax.scatter(x, y, c=c, s=s, cmap=plt.cm.jet)

fig.colorbar(im, ax=ax)
im.set_clim(0,1)

# %% [markdown]
# __polar__

# %%
fig = plt.figure()
axes = fig.add_axes([0.0,0.0,0.8,0.8], polar=True)
t = np.linspace(0, 2 * np.pi, 100)
axes.plot(t, t, color='blue', lw=3);

# %% [markdown]
# __Histogram__

# %%
n = np.random.randn(10000);

fig, axes = plt.subplots(1,2, figsize=(12,4))

axes[0].hist(n)
axes[0].set_xlim((min(n), max(n)))
axes[0].set_title('Default histogram')

axes[1].hist(n, cumulative=True, bins=50, color='blue', alpha=0.5)
axes[1].set_xlim((min(n),max(n)))
axes[1].set_title('Cumulative detailed histogram')

# %% [markdown]
# __2D Histograms and Hexbim__

# %%
x, y = np.random.normal(size=(2,1000))

fig, ax = plt.subplots(1,2, figsize=(8,4))
im = ax[0].hexbin(x, y, gridsize=20)
fig.colorbar(im, ax=ax[0])

H = ax[1].hist2d(x,y,bins=20)
fig.colorbar(H[3], ax=ax[1])

# %% [markdown]
# __Pie Plot__

# %%
fracs = [30, 15, 30, 15]
colors = ['b', 'g', 'r', 'w']

fig, ax = plt.subplots(figsize=(6, 6))
pie = ax.pie(fracs, colors=colors, explode=(0.05, 0, 0.05, 0), shadow=True,
             labels=['A', 'B', 'C', 'D'])

# %% [markdown]
# __Error Plots__

# %%
x = np.linspace(0,10,25)
dy = 0.1
y = np.random.normal(np.sin(x), dy)

fig, ax = plt.subplots(1,2, figsize=(8,4))
ax[0].plot(x,y)

ax[1].errorbar(x,y,dy, fmt='.k')
# Out:
# <Container object of 3 artists>

# %% [markdown]
# ### Text annotation

# %%
x = np.linspace(-1,1,100)

fig, axes = plt.subplots()

axes.plot(x, x**2, x, x**3)

axes.text(-0.7, 0.6, r'$y=x^2$', fontsize=18, color='blue')
axes.text(-0.7, -0.5, r'$y=x^3$', fontsize=18, color='green')

# %% [markdown]
# ### Figures with multiple subplots and insets

# %%
fig, ax = plt.subplots(2,3, figsize=(12,6))
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax5 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax3 = plt.subplot2grid((3,3), (2,0), colspan=1)
ax4 = plt.subplot2grid((3,3), (2,1), colspan=1)
fig.tight_layout()

# %% [markdown]
# __gridspec__

# %%
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure()

gs = gridspec.GridSpec(2,3, height_ratios=[2,1], width_ratios=[1,2,1])
for g in gs:
    axes = fig.add_subplot(g)
    
fig.tight_layout()

# %% [markdown]
# __add_axes__

# %%
fig, ax = plt.subplots()

ax.plot(x, x**2, x, x**3)
fig.tight_layout()

# inset
inset_ax = fig.add_axes([0.6, 0.15, 0.3, 0.3])

inset_ax.plot(x, x**2, x, x**3)
inset_ax.set_title('zoom near origin')

# set axis range
inset_ax.set_xlim(-0.2, 0.2)
inset_ax.set_ylim(-0.005, 0.01)

# set axis tick location
inset_ax.set_yticks([0, 0.005, 0.01])
inset_ax.set_xticks([-0.1, 0, 0.1])

# %% [markdown]
# ### Colormap and contour figures

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5
def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %% [markdown]
# __pcolor__

# %%
fig, ax = plt.subplots()

p = ax.pcolor(X/(2*np.pi), Y/(2*np.pi), Z, cmap=matplotlib.cm.RdBu,
             vmin=abs(Z).min(), vmax=abs(Z).max())
cb = fig.colorbar(p, ax=ax)

# %% [markdown]
# __imshow__

# %%
fig, ax = plt.subplots()

im = ax.imshow(Z, cmap=matplotlib.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())
im.set_interpolation('bilinear')

cb = fig.colorbar(im, ax=ax)

# %% [markdown]
# __contour__

# %%
fig, ax = plt.subplots()

cnt = ax.contour(Z, cmap=matplotlib.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())

# %% [markdown]
# ### 3D figures

# %%
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# __surface plots__

# %%
fig = plt.figure(figsize=(14,6))

ax = fig.add_subplot(1,2,1, projection='3d')
p = ax.plot_surface(X,Y,Z, rstride=4, cstride=4, lw=0)

ax = fig.add_subplot(1,2,2, projection='3d')
p = ax.plot_surface(X,Y,Z, rstride=2, cstride=1, cmap=matplotlib.cm.coolwarm, lw=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %% [markdown]
# __Wire-frame plots__

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection='3d')

p = ax.plot_wireframe(X,Y,Z, rstride=4, cstride=4)

# %% [markdown]
# __Contour plots with projections__

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X,Y,Z, rstride=4, cstride=4, alpha=0.25)

cset = ax.contour(X, Y, Z, zdir='z', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=3*np.pi, cmap=matplotlib.cm.coolwarm)

ax.set_xlim3d(-np.pi, 2*np.pi)
ax.set_ylim3d(0, 3*np.pi)
ax.set_zlim3d(-np.pi, 2*np.pi)
# Out:
# (-3.141592653589793, 6.283185307179586)

# %% [markdown]
# __Change the view angle__

# %%
fig = plt.figure(figsize=(12,6))

ax = fig.add_subplot(1,2,1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
ax.view_init(30, 45)

ax = fig.add_subplot(1,2,2, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
ax.view_init(70, 30)

fig.tight_layout()

# %% [markdown]
# ### Animations

# %%
from matplotlib import animation

# %%
# solve the ode problem of the double compound pendulum again

from scipy.integrate import odeint
from numpy import cos, sin

g = 9.82; L = 0.5; m = 0.1

def dx(x, t):
    x1, x2, x3, x4 = x[0], x[1], x[2], x[3]
    
    dx1 = 6.0/(m*L**2) * (2 * x3 - 3 * cos(x1-x2) * x4)/(16 - 9 * cos(x1-x2)**2)
    dx2 = 6.0/(m*L**2) * (8 * x4 - 3 * cos(x1-x2) * x3)/(16 - 9 * cos(x1-x2)**2)
    dx3 = -0.5 * m * L**2 * ( dx1 * dx2 * sin(x1-x2) + 3 * (g/L) * sin(x1))
    dx4 = -0.5 * m * L**2 * (-dx1 * dx2 * sin(x1-x2) + (g/L) * sin(x2))
    return [dx1, dx2, dx3, dx4]

x0 = [np.pi/2, np.pi/2, 0, 0]  # initial state
t = np.linspace(0, 10, 250) # time coordinates
x = odeint(dx, x0, t)    # solve the ODE problem

# %%
fig, ax = plt.subplots(figsize=(5,5))

ax.set_ylim([-1.5, 0.5])
ax.set_xlim([1, -1])

pendulum1, = ax.plot([], [], color="red", lw=2)
pendulum2, = ax.plot([], [], color="blue", lw=2)

def init():
    pendulum1.set_data([], [])
    pendulum2.set_data([], [])

def update(n): 
    # n = frame counter
    # calculate the positions of the pendulums
    x1 = + L * sin(x[n, 0])
    y1 = - L * cos(x[n, 0])
    x2 = x1 + L * sin(x[n, 1])
    y2 = y1 - L * cos(x[n, 1])
    
    # update the line data
    pendulum1.set_data([0 ,x1], [0 ,y1])
    pendulum2.set_data([x1,x2], [y1,y2])

anim = animation.FuncAnimation(fig, update, init_func=init, frames=len(t), blit=True)

# anim.save can be called in a few different ways, some which might or might not work
# on different platforms and with different versions of matplotlib and video encoders
#anim.save('animation.mp4', fps=20, extra_args=['-vcodec', 'libx264'], writer=animation.FFMpegWriter())
#anim.save('animation.mp4', fps=20, extra_args=['-vcodec', 'libx264'])
#anim.save('animation.mp4', fps=20, writer="ffmpeg", codec="libx264")
anim.save('animation.mp4', fps=20, writer="avconv", codec="libx264")

plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-6e7bfc25cf91> in <module>()
#      23     pendulum2.set_data([x1,x2], [y1,y2])
#      24
# ---> 25 anim = animation.FuncAnimation(fig, update, init_func=init, frames=len(t), blit=True)
#      26
#      27 # anim.save can be called in a few different ways, some which might or might not work
#
# C:\Anaconda2\lib\site-packages\matplotlib\animation.pyc in __init__(self, fig, func, frames, init_func, fargs, save_count, **kwargs)
#    1163         self._save_seq = []
#    1164
# -> 1165         TimedAnimation.__init__(self, fig, **kwargs)
#    1166
#    1167         # Need to reset the saved seq, since right now it will contain data
#
# C:\Anaconda2\lib\site-packages\matplotlib\animation.pyc in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1007
# ...

# %% [markdown]
# ### Backends

# %%
print(matplotlib.rcsetup.all_backends)

# %% [markdown]
# __SVG__

# %%
import matplotlib
matplotlib.use('svg')
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image, SVG

# %%
fig, ax = plt.subplots()
t = np.linspace(0, 10, 100)
ax.plot(t, np.cos(t)*np.sin(t))
plt.savefig('svg_test.svg')

# %%
SVG(filename='svg_test.svg')

# %%
# %matplotlib inline 
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
t = np.linspace(0, 10, 100)
ax.plot(t, np.cos(t)*np.sin(t))

# %% [markdown]
# __interactive Backend__

# %%
import matplotlib
matplotlib.use('Qt4Agg')
import matplotlib.pylab as plt
import numpy as np

# %%
fig, ax = plt.subplots()
t = np.linspace(0, 10, 100)
ax.plot(t, np.cos(t)*np.sin(t))
plt.show()
